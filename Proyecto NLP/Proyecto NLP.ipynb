# %% [markdown]
# ## Importaciones

# %% [markdown]
# Primero realizaremos las importaciones de librerias necesarias para el código

# %%
import pandas as pd
import re
import spacy
import re
import pickle
from emot.emo_unicode import UNICODE_EMOJI # For emojis
from emot.emo_unicode import EMOTICONS_EMO # For EMOTICONS

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# Posteriormente cargamos el dataset con el cual vamos a trabajar y lo tratamos

# %%
df = pd.read_csv("data_final.csv")

# %% [markdown]
# Creamos una lista con los tweets usados, de la siguiente forma

# %%
lista_tweets = df["Tweet"].values.tolist()

# %% [markdown]
# ### Limpiar caracteres innecesarios

# %%
def limpiar(texto):
    puntuación = r'[,;.:¡!¿?@#$%&[\](){}<>~=+\-*/|\\_^`"\'—━]'
    
    
    #links
    links = r'(https?:\/\/)?([\da-z\.-]+)\.([a-z\.]{2,6})([\/\w \.-]*)'
    texto = re.sub(links, ' ', texto)
    
    # signos de puntuación
    texto = re.sub(puntuación, ' ', texto)
    
    # dígitos [0-9]
    texto = re.sub('\d', ' ', texto)

    return texto

# %% [markdown]
# ### Función para quitar emojis

# %%
# 'Emoji_Dict.p'- download link https://drive.google.com/open?id=1G1vIkkbqPBYPKHcQ8qy0G2zkoab2Qv4v
with open('Emoji_Dict.p', 'rb') as fp:
    Emoji_Dict = pickle.load(fp)
Emoji_Dict = {v: k for k, v in Emoji_Dict.items()}

def desemojizar(text):
    for emot in Emoji_Dict:
        text = re.sub(r'('+emot+')', "_".join(Emoji_Dict[emot].replace(",","").replace(":","").split()), text)
    return text

# %% [markdown]
# ### Normalizar

# %%
def normalizar(texto):
    # todo a minúsculas
    texto = texto.lower()

    # tildes y diacríticas
    texto = re.sub('á', 'a', texto)
    texto = re.sub('é', 'e', texto)
    texto = re.sub('í', 'i', texto)
    texto = re.sub('ó', 'o', texto)
    texto = re.sub('ú', 'u', texto)
    texto = re.sub('ü', 'u', texto)
    texto = re.sub('ñ', 'n', texto)

    return texto

# %% [markdown]
# ### Tokenizar

# %%
nlp = spacy.load('es_core_news_sm')
def tokenizar(texto):
    # IMPORTANTE: podría devolver una lista vacía
    return [tóken for tóken in texto.split()]

# %% [markdown]
# ### Función preprocesar que ejecuta todas las anteriores

# %%
def preprocesar(texto):
    texto = limpiar(texto)
    texto = desemojizar(texto)
    texto = normalizar(texto)
    texto = tokenizar(texto)

    return texto

# %% [markdown]
# ### Ejecutamos la función

# %%
attributes_container = []


for i in range(len(lista_tweets)):
        if i>200:
            break
        data_procesada = preprocesar(lista_tweets[i])
        attributes_container.append(data_procesada)

# %%
print(attributes_container)
# Out:
# [['ademas', 'no', 'no', 'puedo', 'darte', 'una', 'respuesta', 'con', 'toda', 'certeza', 'musito', 'cruzandose', 'de', 'brazos', 'en', 'defensa', 'propia', 'ante', 'tan', 'extrana', 'conversacion', 'no', 'queria', 'que', 'acabase', 'pero', 'tampoco', 'le', 'producia', 'comodidad', 'pero', 'se', 'que', 'hay', 'algo', 'mas', 'poderoso', 'que', 'mis', 'poderes', 'sanadores', '›'], ['comenzare', 'a', 'aplicar', 'la', 'de', 'respuesta', 'real', 'o', 'respuesta', 'generica'], ['juanest', 'ministerio', 'tic', 'ya', 'tenemos', 'tu', 'comunicacion', 'via', 'mensaje', 'privado', 'juanest', 'queremos', 'ayudarte', 'con', 'tu', 'requerimiento', 'en', 'unos', 'momentos', 'uno', 'de', 'nuestros', 'expertos', 'estara', 'brindando', 'respuesta', 'al', 'requerimiento'], ['osvaldo', 'gimenez', 'buenas', 'noches', 'hoy', 'hace', 'exactamente', 'dias', 'que', 'estoy', 'esperando', 'una', 'respuesta', 'mas', 'amplia', 'al', 'estamos', 'trabajando', 'en', 'tu', 'caso'], ['xsparkoflight', 'black', 'es', 'la', 'unica', 'respuesta', 'correcta', 'susana'], ['lalo', 'brito', 'dijo', 'en', 'una', 'entrevista', 'de', 'hoy', 'que', 'se', 'trato', 'el', 'tema', 'de', 'menstruacion', 'en', 'un', 'capitulo', 'de', 'la', 'serie', 'ademas', 'menciono', 'que', 'se', 'viralizo', 'un', 'video', 'en', 'tiktok', 'al', 'respecto', 'es', 'de', 'mi', 'autoria', 'y', 'que', 'tuvo', 'una', 'muy', 'buena', 'respuesta', 'de', 'parte', 'del', 'publico', 'red_heart️', 'papasporencargo'], ['amcquito', 'sigo', 'esperando', 'su', 'respuesta', 'no', 'han', 'atendido', 'este', 'oficio', 'desde', 'el', 'de', 'diciembre', 'isacarmigniani', 'paulcoellosegar'], ['editorialjvd', 'ante', 'la', 'propuesta', 'del', 'ab', 'jaime', 'nebot', 'de', 'convertir', 'a', 'ecuador', 'en', 'una', 'republica', 'federal', 'es', 'realmente', 'esa', 'la', 'solucion', 'quienes', 'son', 'los', 'culpables', 'de', 'que', 'hoy', 'ecuador', 'sea', 'un', 'estado', 'fallido', 'aqui', 'la', 'respuesta', 'losmiserables', 'ecuador', 'guayaquil', 'ultimahora'], ['lecat', 'snowsinner', 'marcada', 'como', 'propiedad', 'de', 'alguien', 'su', 'clan', 'necesitaba', 'un', 'lider', 'y', 'los', 'hilos', 'enredados', 'siempre', 'se', 'movian', 'gracias', 'a', 'las', 'artimanas', 'o', 'manejos', 'por', 'parte', 'de', 'la', 'muchacha', 'nego', 'rotundamente', 'su', 'respuesta', 'ya', 'habia', 'sido', 'mas', 'que', 'declarada'], ['mercadopago', 'buenas', 'noches', 'hoy', 'hace', 'exactamente', 'dias', 'que', 'estoy', 'esperando', 'una', 'respuesta', 'mas', 'amplia', 'al', 'estamos', 'trabajando', 'en', 'tu', 'caso'], ['es', 'efectivamente', 'un', 'nicho', 'abierto', 'el', 'problema', 'es', 'que', 'los', 'tiempos', 'de', 'respuesta', 'son', 'altos', 'y', 'las', 'fake', 'news', 'se', 'desmienten', 'cuando', 'su', 'efecto', 'desinformador', 'ya', 'se', 'ha', 'instalado', 'las', 'fake', 'news', 'no', 'solo', 'instalan', 'falso', 'contenido', 'sino', 'que', 'ademas', 'un', 'clima'], ['renzuc', 'lo', 'escuche', 'y', 'fue', 'una', 'respuesta', 'media', '“dictatorial”', 'estaba', 'nervioso', 'y', 'absolutamente', 'derrotista', 'se', 'mueve', 'en', 'la', 'silla', 'de', 'un', 'lado', 'a', 'otro', 'atrapado', 'y', 'diciendo', 'algo', 'q', 'no', 'sabe', 'si', 'debe', 'decir', 'conclusion', 'sepulto', 'al', 'apruebo', 'o', 'es', 'lo', 'q', 'nos', 'quieren', 'hacer', 'creer', 'rechazoganael', 'deseptiembre'], ['lyscamander', 'sonrio', 'con', 'dulzura', 'por', 'su', 'respuesta', 'que', 'lindo', 'que', 'eres', 'lysander'], ['pero', 'por', 'que', 'una', 'marcha', 'para', 'las', 'transmasculinidades', 'y', 'las', 'personas', 'no', 'binarias', 'asignadas', 'femenino', 'al', 'nacer', 'la', 'respuesta', 'la', 'da', 'la', 'misma', 'red', '“para', 'celebrar', 'sus', 'vidas', 'abrazarnos', 'y', 'azotar', 'baldosas”'], ['hoy', 'por', 'primera', 'vez', 'thiago', 'escucho', 'el', 'himno', 'de', 'venezuela', 'estando', 'mas', 'consciente', 'y', 'si', 'respuesta', 'fue', 'oh', 'vaya', 'astonished_face', 'asi', 'que', 'ninitas', 'toda', 'nuestras', 'energi ...

# %%
with open('lista_tweets.pickle', 'wb') as handle:  #writing bites 
    pickle.dump(attributes_container, handle, protocol=pickle.HIGHEST_PROTOCOL)
